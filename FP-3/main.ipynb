# %% [markdown]
# # Final Project FP-3:  Descriptive Statistics (Example)
#
#
# <br>
# <br>

# %% [markdown]
# ___
#
# <br>
#
# # Relationship between CO2 Emissions and Economic Growth
#
#
# * **Name**:  Sho IWATO
# * **Student number**:  0500370767
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * The purpose of this Final Project is to analayze the relationship between CO2 emissions and economic growth in different countries.
# * The key **dependent variable** (DV) is the annual CO2 emissions per country(measured in metric tons).
# * Key **independent variables** (IVs) include:
#     * gdp per capita
#     * population
#     * year
# * This dataset contains data for about 200 countries across 60 years (from 1960 to 2020).
# Each country-year record includes values for all independent variables (IVs) as well as the dependent variable (DV).
# <br>

# %% [markdown]
# ### Dataset source:
#
# The data come from the [CO₂ and Greenhouse Gas Emissions](https://ourworldindata.org/co2-and-greenhouse-gas-emissions) dataset provided by [Our World in Data](https://ourworldindata.org/).
#
# The dataset compiles information from multiple reliable sources, including the [Global Carbon Project](https://www.globalcarbonproject.org/), [World Bank Open Data](https://data.worldbank.org/), and [United Nations](https://data.un.org/).
#
# The data are freely available for download [here](https://ourworldindata.org/co2-and-greenhouse-gas-emissions).
#
# #### References:
#
# Our World in Data. “CO₂ and Greenhouse Gas Emissions.”
# Available at: https://ourworldindata.org/co2-and-greenhouse-gas-emissions
#
# World Bank Open Data. “World Development Indicators.”
# Available at: https://data.worldbank.org/

# %% [markdown]
# ___
#
# ## Descriptive Statistics

# %%
# %%capture
# %run descriptive.ipynb

# %%
display_central_tendency_table(num=1)
display_dispersion_table(num=2)
# Out:
# <br><br><p><span style="font-size: 1.2em;"><b>Table 1</b>: Central tendency summary statistics.</span></p>
#         co2_emissions  gdp_per_capita    population         year
# mean       415.698178    3.300495e+11  5.686141e+07  1919.883067
# median            NaN             NaN           NaN  1924.000000
# mode              NaN             NaN           NaN  1994.000000
# <br><br><p><span style="font-size: 1.2em;"><b>Table 2</b>: Dispersion summary statistics.</span></p>
#          co2_emissions  gdp_per_capita    population         year
# st.dev.    1945.810581    3.086282e+12  3.199866e+08    65.626642
# min           0.000000    4.998000e+07  2.150000e+02  1750.000000
# max       37791.570000    1.301126e+14  8.091735e+09  2023.000000
# range     37791.570000    1.301125e+14  8.091735e+09   273.000000
# 25th               NaN             NaN           NaN  1875.000000
# 75th               NaN             NaN           NaN  1974.000000
# ...

# %%
plot_descriptive()
