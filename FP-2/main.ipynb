# %% [markdown]
# # main.ipynb
#
# This notebook runs the data parsing notebook `parse_data.ipynb` and reports a summary.

# %%
# %run parse_data.ipynb

# %%
df.describe()
# Out:
#        CO2_emissions  GDP_per_capita          year
# count   29137.000000    1.525100e+04  50191.000000
# mean      415.698178    3.300495e+11   1919.883067
# std      1945.843973    3.086383e+12     65.627296
# min         0.000000    4.998000e+07   1750.000000
# 25%         0.374000    7.874038e+09   1875.000000
# 50%         4.990000    2.743861e+10   1924.000000
# 75%        53.273000    1.212627e+11   1974.000000
# max     37791.570000    1.301126e+14   2023.000000
